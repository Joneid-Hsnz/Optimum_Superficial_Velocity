# %% [markdown]
# This is a demo of a tranied machine learning model that is able to estimate an optimum superficial velocity in a bed of granulated blast furnace slag that is is fluized by 2 different configurations of air-ditributor plates (Bubble Tray and Bubble Cap).
#
# Develpoed by Seyyed Joneid Hasannejad in IET of Vienna University of Technology.

# %%
#@title Setup{ vertical-output: false, run: "auto", display-mode: "form" }
#@markdown Please run this cell by clicking on the play icon on the left or pressing Shift+Enter


# !git clone https://github.com/Joneid-Hsnz/Optimum_Superficial_Velocity.git
# %cd Optimum_Superficial_Velocity/

# %%
#@title Start{ vertical-output: false, run: "auto", display-mode: "form" }
#@markdown In order to estimate the optimum superficial velocity of gas in your fluidized bed please run this cell and enter necessary values which are:

#@markdown PR: Pressure ratio 0.20 - 0.40

#@markdown AR:  Ratio of min open area in the air distributor to total bed cross sectional area

#@markdown AR for standard Bubble tray= 0.010178 and for standard Bubble Cap= 0.012314

#@markdown Height: Bed Height in mm



# !python Estimate_Velocity.py
